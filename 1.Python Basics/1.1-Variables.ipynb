# %%
a=100

# %%
##declearing and Assigning Variables
age=32
height=6.1
name="abdul"
is_student=True
##printing the variables
print("age:",age)
print("Height:",height)
print("Name:",name)
print("Student:",is_student)
# Out:
# age: 32
# Height: 6.1
# Name: abdul
# Student: True

# %%
##Naming Conventions
##Variable names should be dicriptive
##They must start with a letter or an'_' and contains letter,numers and underscores
##variables names are case sensitive

##valid variable name 
first_name="Abdul"
last_name="Rahman"

# %%
##invalid variable name
#2age=30
#first-name="abdul"
##@name="abdul"

# %%
##case sensetive
name="Abdul"
Name="Rahman"

# %%
##understanding Variable types
##python is dynamically typedtype of a variable is determined at runtime
age=25#int
height=6.1#float
name="Abdul"
is_student=True#bool
print(type(name))
# Out:
# <class 'str'>

# %%
##type checking and conversion
type(height)
# Out:
# float

# %%
age=25
print(type(age))

#type conversion
age_str=str(age)
print(type(age_str))
age='25'
print(type(age))
# Out:
# <class 'int'>
# <class 'str'>
# <class 'str'>

# %%
name="Abdul"
int(name)#error
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[11], line 2
#       1 name="Abdul"
# ----> 2 int(name)#error
#
# ValueError: invalid literal for int() with base 10: 'Abdul'

# %%
height=6.4
type(height)
# Out:
# float

# %%
int(height)
# Out:
# 6

# %%
float(int(height))
# Out:
# 6.0

# %%
##Dynamic typing
##python allows the types of variable to change as the program executes
var=10#int
print(var,type(var))

var="Hello"
print(var,type(var))

var=3.14
print(var,type(var))
# Out:
# 10 <class 'int'>
# Hello <class 'str'>
# 3.14 <class 'float'>

# %%
##input
age=input("What is the age")
print(age,type(age))


age=int(input("What is the age"))
print(age,type(age))
# Out:
# 32 <class 'str'>
# 32 <class 'int'>

# %%
##simple calculator
num1=float(input("Enter first number"))
num2=float(input("Enter Second nunmber"))
