# %% [markdown]
# Comparision operators

# %%
##Arithmethic Operation
a=10
b=6
add_res=a+b
sub_res=a-b
mul_res=a*b
div_res=a/b
floor_div_res=a//b
modulus_res=a%b
exponent_res=a**b
print(add_res)
print(sub_res)
print(div_res)
print(floor_div_res)
print(modulus_res)
print(exponent_res)
# Out:
# 16
# 4
# 1.6666666666666667
# 1
# 4
# 1000000

# %%
##comparison Operators
##==
a=10
b=10
a==b
result=(a==b)
print(result)
# Out:
# True

# %%
str1="Abdul"
str2="Abdul"
str1==str2
# Out:
# False

# %%
str1="abdul"
str1==str2
# Out:
# False

# %%
str1="Abdul"
str2="Abdul"
str1!=str2
# Out:
# False

# %%
##greater than
num1=45
num2=55
num1>num2
# Out:
# False

# %%
##greater than equal to 
num1=45
num2=45
num1>=num2
# Out:
# True

# %% [markdown]
# Logical Operators

# %%
##And,Not,Or
X=True
Y=True
result=X and Y
print(result)
X=False
result=X or Y
print(result)
not Y
# Out:
# True
# True
# False
