# %%
## Basic Syntax Rules in Python
## Case sensitivity : python is case sensitive

name="Abdul"
Name="Rahman"
print(name)
print(Name)
# Out:
# Abdul
# Rahman

# %% [markdown]
# Indentation

# %% [markdown]
# Indentaion in Python is used to define the structure and hierarchy of the code. Unlike many other progra lang that use braces{} to delimit block of code.python uses inden to determine the grouping of statements . this means that all the statements within  block must be indented at the same level

# %%
#indentatinon
age=32
if age>30:
    print(age)
print(age)
# Out:
# 32
# 32

# %%
print("Hello World")
# Out:
# Hello World

# %%
##Line continuation
total=1+2+3+4+\
6+3+5
print(total)
# Out:
# 24

# %%
##Multiple Statements on a single line
x=5;y=10;z=x*y
print(z)
# Out:
# 50

# %%
##understand semantics in python
# variable assignment
age=32 ##age is an integer
name="abdul"

# %%
type(age)
# Out:
# int

# %%
type(name)
# Out:
# str

# %%
##type inference
variable=10
print(type(variable))
variable="Abdul"
print(type(variable))
# Out:
# <class 'int'>
# <class 'str'>

# %%
##Name error
a=b
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[10], line 2
#       1 ##Name error
# ----> 2 a=b
#
# NameError: name 'b' is not defined

# %%
##code examples of indenation
if True:
    print("Current Indentation")
    if False:
        print("This not print")
    print("This will print")
print("OutSide the if block")
# Out:
# Current Indentation
# This will print
# OutSide the if block
