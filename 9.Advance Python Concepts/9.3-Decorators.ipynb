# %% [markdown]
# #### Decorators

# %%
## function copy
## closures
## decorators

# %%
## function copy
def welcome():
    return "Welcome to the advanced python course by Udemy"

welcome()
# Out:
# 'Welcome to the advanced python course by Udemy'

# %%
wel=welcome
print(wel())
del welcome
print(wel())
# Out:
# Welcome to the advanced python course by Udemy
# Welcome to the advanced python course by Udemy

# %%
## closures functions

def main_welcome():
    msg="Welcome"
    def sub_welcome_method():
        print("Welcome to the advance python course")
        print(msg)
        print("Please learn these concepts properyly")
    return sub_welcome_method()

# %%
main_welcome()
# Out:
# Welcome to the advance python course
# Welcome
# Please learn these concepts properyly

# %%
## closures functions

def main_welcome(func):
    msg="Welcome"
    def sub_welcome_method():
        print("Welcome to the advance python course")
        func("Welcom every one to this tutorial")
        print("Please learn these concepts properyly")
    return sub_welcome_method()

# %%
main_welcome(print)
# Out:
# Welcome to the advance python course
# Welcom every one to this tutorial
# Please learn these concepts properyly

# %%
## closures functions

def main_welcome(func,lst):
    msg="Welcome"
    def sub_welcome_method():
        print("Welcome to the advance python course")
        print(func(lst))
        print("Please learn these concepts properyly")
    return sub_welcome_method()

# %%
main_welcome(len,([1,2,3,4,5,6]))
# Out:
# Welcome to the advance python course
# 6
# Please learn these concepts properyly

# %%
## decorator
## closures functions

def main_welcome(func):
    msg="Welcome"
    def sub_welcome_method():
        print("Welcome to the advance python course")
        func()
        print("Please learn these concepts properyly")
    return sub_welcome_method()

# %%
def course_introduction():
    print("This is an advanced python course")

course_introduction()
# Out:
# This is an advanced python course

# %%
main_welcome(course_introduction)
# Out:
# Welcome to the advance python course
# This is an advanced python course
# Please learn these concepts properyly

# %%
@main_welcome
def course_introduction():
    print("This is an advanced python course")
# Out:
# Welcome to the advance python course
# This is an advanced python course
# Please learn these concepts properyly

# %%
## decorator

def my_decorator(func):
    def wrapper():
        print("Something is happening before the function is called.")
        func()
        print("Something is happening after the function is called")
    return wrapper

# %%
@my_decorator
def say_hello():
    print("Hello!")

# %%
say_hello()
# Out:
# Something is happening before the function is called.
# Hello!
# Something is happening after the function is called

# %%
## Decorators with arguments
def repeat(n):
    def decorator(func):
        def wrapper(*args,**kwargs):
            for _ in range(n):
                func(*args,**kwargs)
        return wrapper
    return decorator

# %%
@repeat(3)
def say_hello():
    print("Hello!")

# %%
say_hello()
# Out:
# Hello!
# Hello!
# Hello!
