# %% [markdown]
# #### Generators

# %%
def square(n):
    for i in range(3):
        return i**2

# %%
square(3)
# Out:
# 0

# %%
def square(n):
    for i in range(3):
        yield i**2

# %%
square(3)
# Out:
# <generator object square at 0x0000023B654CBED0>

# %%
for i in square(3):
    print(i)
# Out:
# 0
# 1
# 4

# %%
a=square(3)
a
# Out:
# <generator object square at 0x0000023B654CA740>

# %%
next(a)
# Out:
# 0

# %%
next(a)
# Out:
# 1

# %%
next(a)
# Out:
# 4

# %%
def my_generator():
    yield 1
    yield 2
    yield 3

# %%
gen=my_generator()
gen
# Out:
# <generator object my_generator at 0x0000023B6535D380>

# %%
next(gen)
# Out:
# ---------------------------------------------------------------------------
# StopIteration                             Traceback (most recent call last)
# Cell In[15], line 1
# ----> 1 next(gen)
#
# StopIteration:

# %%
for val in gen:
    print(val)
# Out:
# 1
# 2
# 3

# %%
## Practical : Reading Large files

def read_large_file(file_path):
    with open(file_path,'r') as file:
        for line in file:
            yield line

# %%
file_path='large_file.txt'
for line in read_large_file(file_path):
    print(line.strip())
# Out:
# Major rules while writing SOP :
#
# The evaluators typically spend 1–2 minutes per SOP, so they look for:
#
# Genuine interest in ML/AI.
# Evidence that you've already worked on ML.
# Why you want to learn from Amazon scientists.
# How you'll use the knowledge afterward.
# Clarity and impact not fancy English.
