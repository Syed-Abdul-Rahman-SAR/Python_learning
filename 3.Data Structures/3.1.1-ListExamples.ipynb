# %% [markdown]
# Create a To Do List To keep track of tasks

# %%
to_do_list=["Buy Groceries","Clean the house","Pay bills"]

## Adding to task
to_do_list.append("Schedule Meeting")
to_do_list.append("Go for a Run")

## removing a completed task
to_do_list.remove("Clean the house")

## checking if the task is in the list
if "Pay bills" in to_do_list:
    print("Don't forgat to pay the utility bills")

print("To Do List remaining")
for task in to_do_list:
    print(f"-{task}")
# Out:
# Don't forgat to pay the utility bills
# To Do List remaining
# -Buy Groceries
# -Pay bills
# -Schedule Meeting
# -Go for a Run

# %% [markdown]
# #### create a list to store and calculate aberage grades for students

# %%
## orgainzing students grades
grades = [85,92,78,90,88]

##Adding a new grade
grades.append(95)

## calculating the average grade
average_grade=sum(grades)/len(grades)
print(f"Average Grade:{average_grade:.2f}")
# Out:
# Average Grade:88.00
