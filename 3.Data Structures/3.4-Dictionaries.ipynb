# %%
 ## creating Dictionaries
empty_dict={}
print(type(empty_dict))
# Out:
# <class 'dict'>

# %%
empty_dict=dict()
empty_dict
# Out:
# {}

# %%
student={"name":"Abdul","age":21,"grade":8.21}
print(student)
print(type(student))
# Out:
# {'name': 'Abdul', 'age': 21, 'grade': 8.21}
# <class 'dict'>

# %%
## single key is always used
student={"name":"Abdul","age":21,"name":24}
print(student)
# Out:
# {'name': 24, 'age': 21}

# %%
## accessing dictionary elements
student={"name":"Abdul","age":21,"grade":8.21}
print(student)
# Out:
# {'name': 'Abdul', 'age': 21, 'grade': 8.21}

# %%
print(student['grade'])
print(student['age'])

##Accessing using get() method
print(student.get('grade'))
print(student.get('last_name'))
print(student.get('last_name',"Not Available"))
# Out:
# 8.21
# 21
# 8.21
# None
# Not Available

# %%
## modifying dicitonary elements
## dictionary are mutable,so you can add,update or delete elements
print(student)
# Out:
# {'name': 'Abdul', 'age': 21, 'grade': 8.21}

# %%
student["age"]=33 ##update value for the key
print(student)
student["address"]="India" ##added a new key and value
print(student)
# Out:
# {'name': 'Abdul', 'age': 33, 'grade': 8.21}
# {'name': 'Abdul', 'age': 33, 'grade': 8.21, 'address': 'India'}

# %%
del student['grade'] ## delete key and vale pair

print(student)
# Out:
# {'name': 'Abdul', 'age': 33, 'address': 'India'}

# %%
## dictionary methods

keys=student.keys() ##get all the keys
print(keys)
values=student.values() ##get all values
print(values)

items=student.items() ##get all key value pairs
print(items)
# Out:
# dict_keys(['name', 'age', 'address'])
# dict_values(['Abdul', 33, 'India'])
# dict_items([('name', 'Abdul'), ('age', 33), ('address', 'India')])

# %%
## shallow copy
student_copy=student
print(student)
print(student_copy)
# Out:
# {'name': 'Abdul', 'age': 33, 'address': 'India'}
# {'name': 'Abdul', 'age': 33, 'address': 'India'}

# %%
student["name"]="Rahman"
print(student)
print(student_copy)
# Out:
# {'name': 'Rahman', 'age': 33, 'address': 'India'}
# {'name': 'Rahman', 'age': 33, 'address': 'India'}

# %%
student_copy1=student.copy() ## shallow copy
print(student_copy1)
print(student)
# Out:
# {'name': 'Rahman', 'age': 33, 'address': 'India'}
# {'name': 'Rahman', 'age': 33, 'address': 'India'}

# %%
student["name"]="syed"
print(student)
print(student_copy1)
# Out:
# {'name': 'syed', 'age': 33, 'address': 'India'}
# {'name': 'Rahman', 'age': 33, 'address': 'India'}

# %%
## iterating over dictionaries
## you can use loops to iterate over dictionaries,keys,values or items

##Iterating over keys
for keys in student.keys():
    print(keys)
# Out:
# name
# age
# address

# %%
## iterate over values
for values in student.values():
    print(values)
# Out:
# syed
# 33
# India

# %%
## iterate over key value pairs
for key,value in student.items():
    print(f"{key}:{value}")
# Out:
# name:syed
# age:33
# address:India

# %%
## nested disctionaries 
students={
    "student1":{"name":"Abdul","age":32},
    "student2":{"name":"Rahman","age":21}
}
print(students)
# Out:
# {'student1': {'name': 'Abdul', 'age': 32}, 'student2': {'name': 'Rahman', 'age': 21}}

# %%
## Access nested dicionaries elements
print(students["student2"]["name"])
print(students["student1"]["age"])
# Out:
# Rahman
# 32

# %%
## iterating over nested dictionaries
for student_id,student_info in students.items():
    print(f"{student_id}:{student_info}")
    for key,value in student_info.items():
        print(f"{key}:{value}")
# Out:
# student1:{'name': 'Abdul', 'age': 32}
# name:Abdul
# age:32
# student2:{'name': 'Rahman', 'age': 21}
# name:Rahman
# age:21

# %%
## dicionary comphrehension
squares={x:x**2 for x in range(5)}
print(squares)
# Out:
# {0: 0, 1: 1, 2: 4, 3: 9, 4: 16}

# %%
## condition dictionary comprehension
evens={x:x**2 for x in range(10) if x%2==0}
print(evens)
# Out:
# {0: 0, 2: 4, 4: 16, 6: 36, 8: 64}

# %%
## prectical examples

## use a dicionary to count the freq of elements in list
numbers=[1,2,2,3,3,3,4,4,4,4,5]
frequency={}
for number in numbers:
    if number in frequency:
        frequency[number]+=1
    else:
        frequency[number]=1
print(frequency)
# Out:
# {1: 1, 2: 2, 3: 3, 4: 4, 5: 1}

# %%
## merge 2 dictionaries into one

dict1={"a":1,"b":2}
dict2={"b":3,"c":4}
merged_dict={**dict1,**dict2}
print(merged_dict)
# Out:
# {'a': 1, 'b': 3, 'c': 4}
